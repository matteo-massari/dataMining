# %% [markdown]
# Prerequisiti
# - Scaricare java 17 da: https://www.oracle.com/it/java/technologies/javase/jdk17-archive-downloads.html
# - usare python 3.10
# - installare i requirements.txt
#
# Possibili dataset
# - Toy Store E-Commerce Database: [Maven+Fuzzy+Factory](https://mavenanalytics.io/data-playground)
# - Online Retail II: [online_retail_II.xlsx](https://archive.ics.uci.edu/dataset/502/online+retail+ii)
# - Retail Data: [new_retail_data.csv](https://www.kaggle.com/datasets/sahilprajapati143/retail-analysis-large-dataset)
# - Microsoft Contoso Retail Data: [ContosoRetailData](https://www.kaggle.com/datasets/bhanuthakurr/cleaned-contoso-dataset?resource=download)

# %%
import os

os.environ["JAVA_HOME"] = "/Library/Java/JavaVirtualMachines/jdk-17.jdk/Contents/Home"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]

# controllo
import subprocess
print(subprocess.run(["java", "-version"], capture_output=True, text=True).stderr)

import findspark
findspark.init()
# Out:
# java version "17.0.12" 2024-07-16 LTS
# Java(TM) SE Runtime Environment (build 17.0.12+8-LTS-286)
# Java HotSpot(TM) 64-Bit Server VM (build 17.0.12+8-LTS-286, mixed mode, sharing)

# %%
# !echo $JAVA_HOME
# !java -version
# !javac -version
# Out:
# /Library/Java/JavaVirtualMachines/jdk-17.jdk/Contents/Home
# java version "17.0.12" 2024-07-16 LTS
# Java(TM) SE Runtime Environment (build 17.0.12+8-LTS-286)
# Java HotSpot(TM) 64-Bit Server VM (build 17.0.12+8-LTS-286, mixed mode, sharing)
# javac 17.0.12

# %% [markdown]
# # Data mining project
# The aim of the project is to create a scalable framework for mining data from a retail store, that works in a dynamic enviroment with in streaming alghotithm  or retrained model.
#
# The Section will be divided in the following steps:
# - Initial analysis of data like simple EDA to understand:
#     - the structure of the data
#     - data quality,
#     - data types
# - The database contains three different types of datasets:
#     - Customer Data
#     - Purchase Data
#     - Product Data
# - Algorithm to apply to the data
#     - Clustering: Using scalable K-Means clustering as BIRH or CURE to allow in stream segmentation of the data.
#     - Market Basket analysis: Using the Apriori algorithm, we extract frequent itemsets and association rules to uncover recurrent purchasing patterns. These rules can be leveraged to identify product bundles, support cross-selling strategies, and serve as a rule-based foundation for a recommendation system.
#     - Recommendation system: Based on collaborative filtering with UV decomposition (ALS in spark) to discover hidden latent factors.
#     The whole analysis analyse the data in different timeframe, to see how the clustering change with the time
#
# Suggestion of the professor
# - sezione temporale
# - distribuzione dei tempi per capire come cambiano i cluster
# - Capire se i tempi sono uniformi
# - Vedere in blocco i parametri come i clustering cambiano con l’aggiunta di nuovi utenti
# - Fare uno studio temporale di come questo algoritmo valutando come arriviano i dati lasciano il tempo come parametro
# - Network che si possono creare
# - Network bipartiti persone - prodotto - persone

# %% [markdown]
# ## Preprocessing
# - Check of the quality of the data
# - Check off the structure of the data
# - Analysis of quantitative variable
# - Analysis of categorical variable

# %%
import pandas as pd
customer_df = pd.read_csv("data/customers.csv")
product_df = pd.read_csv("data/products.csv")
purchase_df = pd.read_csv("data/purchases.csv")

df = purchase_df.merge(customer_df, on="CustomerID").merge(product_df, on="product_id")
df.columns
# Out:
# Index(['InvoiceID', 'date', 'CustomerID', 'product_id', 'quantity',
#        'customer_type', 'item', 'category', 'price', 'type'],
#       dtype='object')

# %%
# Structure of the data
n_row, n_cols = df.shape
print(f"Number of observation: {n_row} \nNumber of feature: {n_cols}")

# Analysis og the columns
print("The Feature are:")
print(df.columns.tolist())

# Analysis of the type of the columns
print(df.dtypes)
# Out:
# Number of observation: 436689
# Number of feature: 10
# The Feature are:
# ['InvoiceID', 'date', 'CustomerID', 'product_id', 'quantity', 'customer_type', 'item', 'category', 'price', 'type']
# InvoiceID          int64
# date              object
# CustomerID         int64
# product_id         int64
# quantity           int64
# customer_type     object
# item              object
# category          object
# price            float64
# type              object
# dtype: object

# %% [markdown]
# Let's analyze the temporal timeframe of this dataset in particular:
# - the starting and the ending time
# - the number of missing days

# %%
date_min = df['date'].min()
date_max = df['date'].max()

all_days = pd.date_range(date_min, date_max, freq='D')
df['date'] = pd.to_datetime(df['date'])
missing_days = all_days.difference(df['date'].dt.normalize().unique())

print("Time Frame: From:", date_min, " to ", date_max)
print("Missing days:", len(missing_days))
# Out:
# Time Frame: From: 2014-01-01  to  2015-12-30
# Missing days: 1

# %% [markdown]
# ## Database Explanation
# In a real setting, we would have three different types of datasets: Demographic Data, Purchase Data, and Feedback Data.
# - Demographic Data contains customer information:
#     - Customer_ID (Int)
#     - customer_type
# - Purchase Data contains transaction and purchase information:
#     - InvoiceID (Int)
#     - Customer_ID (Int, to link with Demographic Data)
#     - Date (Date)
#     - Quantity (Int)
#
# - Product Data contains product information:
#     - Product_ID (Int)
#     - products (String)
#     - Category (String)
#     - Type (String) ("supermarket","Online")
#
# Notes:
# - All three datasets share Customer_ID, which allows joining them.
# - InvoiceID is useful to link purchase and feedback data.
# - Only Demographic data will be solid during the analysis

# %% [markdown]
# ## ETL and Algorithm pipelines
# We have a simulated portion of a retail store database, divided into separate datasets. Two of them: demographic_data and product_data represent master data, containing information that rarely changes and would typically be stored in a database. The other two purchase_data and feedback_data represent temporary or transactional data, generated in real time and likely stored in a data lake.
#
# First of all we create the structure that the different dataset enter in the spark job as a payload

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("data_mining_project") \
    .config("spark.ui.showConsoleProgress", "false") \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/09 18:00:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType, DateType

demographic_scheme = StructType([
    StructField("CustomerID", IntegerType(), True),
    StructField("customer_type", StringType(), True)
])

purchase_scheme = StructType([
    StructField("InvoiceID", IntegerType(), False),
    StructField("date", DateType(), False),
    StructField("CustomerID", IntegerType(), False),
    StructField("product_id", StringType(), False),
    StructField("quantity", IntegerType(), False)
])

product_scheme = StructType([
    StructField("product_id", StringType(), False),
    StructField("item", StringType(), False),
    StructField("category", StringType(), False),
    StructField("price", FloatType(), False),
    StructField("type", StringType(), False)

])

# %%
demographic_df = spark.read.format("csv")\
    .option("header", "true")\
    .schema(demographic_scheme)\
    .load("data/customers.csv")

purchase_df = spark.read.format("csv")\
    .option("header", "true")\
    .schema(purchase_scheme)\
    .load("data/purchases.csv")

product_df = spark.read.format("csv")\
    .option("header", "true")\
    .schema(product_scheme)\
    .load("data/products.csv")

demographic_df.printSchema()
purchase_df.printSchema()
product_df.printSchema()
# Out:
# root
#  |-- CustomerID: integer (nullable = true)
#  |-- customer_type: string (nullable = true)
#
# root
#  |-- InvoiceID: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- CustomerID: integer (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- quantity: integer (nullable = true)
#
# root
#  |-- product_id: string (nullable = true)
#  |-- item: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- price: float (nullable = true)
#  |-- type: string (nullable = true)

# %%
from pyspark.sql.functions import collect_list, col, array_distinct

(product_df.filter(col("type") == "supermarket")).collect()
# Out:
# [Row(product_id='522', item='bottled water', category='Miscellaneous', price=7.610000133514404, type='supermarket'),
#  Row(product_id='601', item='candles', category='Miscellaneous', price=3.569999933242798, type='supermarket'),
#  Row(product_id='1036', item='domestic eggs', category='Miscellaneous', price=1.1699999570846558, type='supermarket'),
#  Row(product_id='1005', item='dishes', category='Miscellaneous', price=3.5899999141693115, type='supermarket'),
#  Row(product_id='1754', item='instant food products', category='Miscellaneous', price=2.2799999713897705, type='supermarket'),
#  Row(product_id='3637', item='tropical fruit', category='Produce', price=3.7300000190734863, type='supermarket'),
#  Row(product_id='3280', item='shopping bags', category='Household', price=1.5499999523162842, type='supermarket'),
#  Row(product_id='565', item='butter', category='Dairy', price=4.840000152587891, type='supermarket'),
#  Row(product_id='2304', item='other vegetables', category='Produce', price=4.980000019073486, type='supermarket'),
#  Row(product_id='3891', item='whole milk', category='Dairy', price=2.190000057220459, type='supermarket'),
#  Row(product_id='4004', item='yogurt', category='Dairy', price=4.489999771118164, type='supermarket'),
#  Row(product_id='837', item='coffee', category='Beverages', price=3.369999885559082, type='supermarket'),
#  Row(product_id='1391', item='frozen potato products', category='Miscellaneous', price=4.510000228881836, type='supermarket'),
#  Row(product_id='1392', item='frozen vegetables', category='Produce', price=5.059999942779541, type='supermarket'),
#  Row(product_id='521', item='bottled beer', category='Beverages', price=2.4700000286102295, type='supermarket'),
#  Row(product_id='803', item='citrus fruit', category='Produce', price=3.559999942779541, type='supermarket'),
#  Row(product_id='3359', item='sliced cheese', category='Dairy', price=3.0199999809265137, type='supermarket'),
#  Row(product_id='3778', item='waffles', category='Bakery & Snacks', price=1.6200000047683716, type='supermarket'),
#  Row(product_id='741', item='chocolate', category='Miscellaneous', price=8.109999656677246, type='supermarket'),
#  Row(product_id='1595', item='hamburger meat', category='Meat', price=13.949999809265137, type='supermarket'),
#  Row(product_id='921', item='curd', category='Dairy', price=1.840000033378601, type='supermarket'),
#  Row(product_id='1284', item='flower (seeds)', category='Gardening', price=14.34000015258789, type='supermarket'),
#  Row(product_id='2281', item='onions', category='Miscellaneous', price=3.509999990463257, type='supermarket'),
#  Row(product_id='547', item='brown bread', category='Bakery & Snacks', price=2.190000057220459, type='supermarket'),
#  Row(product_id='3823', item='whipped/sour cream', category='Dairy', price=1.9700000286102295, type='supermarket'),
#  Row(product_id='3426', item='soda', category='Beverages', price=7.21999979019165, type='supermarket'),
#  Row(product_id='824', item='cleaner', category='Cleaning & Hygiene', price=3.940000057220459, type='supermarket'),
#  Row(product_id='3029', item='sausage', category='Meat', price=11.619999885559082, type='supermarket'),
#  Row(product_id='307', item='berries', category='Produce', price=4.28000020980835, type='supermarket'),
#  Row(product_id='3455', item='specialty chocolate', category='Miscellaneous', price=2.7100000381469727, type='supermarket'),
#  Row(product_id='2956', item='rolls/buns', category='Bakery & Snacks', price=1.8300000429153442, type='supermarket'),
#  Row(product_id='1395', item='fruit/vegetable juice', category='Produce', price=4.050000190734863, type='supermarket'),
#  Row(product_id='2062', item='margarine', category='Condiments & Spices', price=2.8499999046325684, type='supermarket'),
#  Row(product_id='2951', item='roll products', category='Bakery & Snacks', price=3.640000104904175, type='supermarket'),
#  Row(product_id='3667', item='uht-milk', category='Dairy', price=1.9700000286102295, type='supermarket'),
#  Row(product_id='3028', item='sauces', category='Condiments & Spices', price=2.2699999809265137, type='supermarket'),
#  Row(product_id='2237', item='newspapers', category='Household', price=3.369999885559082, type='supermarket'),
#  Row(product_id='1996', item='long life bakery product', category='Bakery & Snacks', price=1.4700000286102295, type='supermarket'),
#  Row(product_id='602', item='candy', category='Miscellaneous', price=8.149999618530273, type='supermarket'),
#  Row(product_id='1341', item='frankfurter', category='Miscellaneous', price=7.050000190734863, type='supermarket'),
#  Row(product_id='303', item='beef', category='Meat', price=6.010000228881836, type='supermarket'),
#  Row(product_id='3424', item='soap', category='Cleaning & Hygiene', price=2.559999942779541, type='supermarket'),
#  Row(product_id='2714', item='pot plants', category='Gardening', price=2.25, type='supermarket'),
#  Row(product_id='2961', item='root vegetables', category='Produce', price=3.430000066757202, type='supermarket'),
#  Row(product_id='979', item='dessert', category='Bakery & Snacks', price=2.9800000190734863, type='supermarket'),
#  Row(product_id='1524', item='grapes', category='Produce', price=3.049999952316284, type='supermarket'),
#  Row(product_id='3046', item='semi-finished bread', category='Bakery & Snacks', price=2.1700000762939453, type='supermarket'),
#  Row(product_id='705', item='chewing gum', category='Miscellaneous', price=6.21999979019165, type='supermarket'),
#  Row(product_id='3835', item='white bread', category='Bakery & Snacks', price=3.5199999809265137, type='supermarket'),
#  Row(product_id='3025', item='salty snack', category='Bakery & Snacks', price=1.0, type='supermarket'),
#  Row(product_id='1648', item='hard cheese', category='Dairy', price=1.4700000286102295, type='supermarket'),
#  Row(product_id='613', item='canned beer', category='Beverages', price=7.96999979019165, type='supermarket'),
#  Row(product_id='2279', item='oil', category='Pantry', price=1.5700000524520874, type='supermarket'),
#  Row(product_id='2464', item='pastry', category='Bakery & Snacks', price=3.7699999809265137, type='supermarket'),
#  Row(product_id='1742', item='ice cream', category='Dairy', price=3.700000047683716, type='supermarket'),
#  Row(product_id='1283', item='flour', category='Pantry', price=5.440000057220459, type='supermarket'),
#  Row(product_id='1753', item='instant coffee', category='Beverages', price=9.520000457763672, type='supermarket'),
#  Row(product_id='1718', item='honey', category='Condiments & Spices', price=4.699999809265137, type='supermarket'),
#  Row(product_id='2726', item='processed cheese', category='Dairy', price=1.399999976158142, type='supermarket'),
#  Row(product_id='2213', item='mustard', category='Condiments & Spices', price=3.0399999618530273, type='supermarket'),
#  Row(product_id='2072', item='meat spreads', category='Meat', price=12.329999923706055, type='supermarket'),
#  Row(product_id='650', item='cat food', category='Pet Care', price=4.760000228881836, type='supermarket'),
#  Row(product_id='831', item='cling film/bags', category='Household', price=1.2599999904632568, type='supermarket'),
#  Row(product_id='1594', item='ham', category='Meat', price=11.930000305175781, type='supermarket'),
#  Row(product_id='1973', item='light bulbs', category='Miscellaneous', price=4.190000057220459, type='supermarket'),
#  Row(product_id='2872', item='red/blush wine', category='Beverages', price=1.0800000429153442, type='supermarket'),
#  Row(product_id='3432', item='soups', category='Miscellaneous', price=6.829999923706055, type='supermarket'),
#  Row(product_id='747', item='chocolate marshmallow', category='Miscellaneous', price=3.5999999046325684, type='supermarket'),
#  Row(product_id='1988', item='liquor', category='Beverages', price=8.859999656677246, type='supermarket'),
#  Row(product_id='2216', item='napkins', category='Household', price=1.5399999618530273, type='supermarket'),
#  Row(product_id='264', item='baking powder', category='Miscellaneous', price=2.9100000858306885, type='supermarket'),
#  Row(product_id='3688', item='vinegar', category='Condiments & Spices', price=1.9800000190734863, type='supermarket'),
#  Row(product_id='1390', item='frozen meals', category='Miscellaneous', price=6.78000020980835, type='supermarket'),
#  Row(product_id='3521', item='sweet spreads', category='Condiments & Spices', price=2.9100000858306885, type='supermarket'),
#  Row(product_id='3509', item='sugar', category='Miscellaneous', price=8.380000114440918, type='supermarket'),
#  Row(product_id='1734', item='hygiene articles', category='Personal Care', price=6.360000133514404, type='supermarket'),
#  Row(product_id='1992', item='liver loaf', category='Meat', price=14.710000038146973, type='supermarket'),
#  Row(product_id='2662', item='pip fruit', category='Produce', price=2.690000057220459, type='supermarket'),
#  Row(product_id='2071', item='meat', category='Meat', price=6.329999923706055, type='supermarket'),
#  Row(product_id='883', item='cream cheese', category='Dairy', price=2.680000066757202, type='supermarket'),
#  Row(product_id='1789', item='jam', category='Condiments & Spices', price=3.0999999046325684, type='supermarket'),
#  Row(product_id='1696', item='herbs', category='Miscellaneous', price=7.159999847412109, type='supermarket'),
#  Row(product_id='2998', item='rum', category='Miscellaneous', price=7.900000095367432, type='supermarket'),
#  Row(product_id='3463', item='spread cheese', category='Dairy', price=3.7300000190734863, type='supermarket'),
#  Row(product_id='309', item='beverages', category='Beverages', price=8.880000114440918, type='supermarket'),
#  Row(product_id='3427', item='soft cheese', category='Dairy', price=4.710000038146973, type='supermarket'),
#  Row(product_id='2492', item='photo/film', category='Household', price=4.909999847412109, type='supermarket'),
#  Row(product_id='2163', item='misc. beverages', category='Beverages', price=2.190000057220459, type='supermarket'),
#  Row(product_id='2067', item='mayonnaise', category='Miscellaneous', price=6.369999885559082, type='supermarket'),
#  Row(product_id='1387', item='frozen dessert', category='Bakery & Snacks', price=3.7100000381469727, type='supermarket'),
#  Row(product_id='2493', item='pickled vegetables', category='Produce', price=1.0399999618530273, type='supermarket'),
#  Row(product_id='4033', item='zwieback', category='Miscellaneous', price=5.599999904632568, type='supermarket'),
#  Row(product_id='3539', item='syrup', category='Condiments & Spices', price=2.25, type='supermarket'),
#  Row(product_id='566', item='butter milk', category='Dairy', price=4.940000057220459, type='supermarket'),
#  Row(product_id='3453', item='specialty bar', category='Miscellaneous', price=2.9200000762939453, type='supermarket'),
#  Row(product_id='2936', item='rice', category='Pantry', price=4.78000020980835, type='supermarket'),
#  Row(product_id='980', item='detergent', category='Cleaning & Hygiene', price=2.0299999713897705, type='supermarket'),
#  Row(product_id='707', item='chicken', category='Meat', price=5.099999904632568, type='supermarket'),
#  Row(product_id='3024', item='salt', category='Condiments & Spices', price=3.5999999046325684, type='supermarket'),
#  Row(product_id='3045', item='seasonal products', category='Condiments & Spices', price=1.3899999856948853, type='supermarket'),
#  Row(product_id='3882', item='white wine', category='Beverages', price=5.75, type='supermarket'),
#  Row(product_id='3646', item='turkey', category='Miscellaneous', price=3.700000047683716, type='supermarket'),
#  Row(product_id='1989', item='liquor (appetizer)', category='Beverages', price=2.0899999141693115, type='supermarket'),
#  Row(product_id='246', item='baby cosmetics', category='Personal Care', price=9.09000015258789, type='supermarket'),
#  Row(product_id='1004', item='dish cleaner', category='Cleaning & Hygiene', price=7.010000228881836, type='supermarket'),
#  Row(product_id='3452', item='sparkling wine', category='Beverages', price=1.5499999523162842, type='supermarket'),
#  Row(product_id='2482', item='pet care', category='Pet Care', price=9.680000305175781, type='supermarket'),
#  Row(product_id='3454', item='specialty cheese', category='Dairy', price=1.5800000429153442, type='supermarket'),
#  Row(product_id='2698', item='popcorn', category='Miscellaneous', price=3.6500000953674316, type='supermarket'),
#  Row(product_id='3429', item='softener', category='Cleaning & Hygiene', price=5.480000019073486, type='supermarket'),
#  Row(product_id='1011', item='dog food', category='Pet Care', price=5.139999866485596, type='supermarket'),
#  Row(product_id='854', item='condensed milk', category='Dairy', price=1.3200000524520874, type='supermarket'),
#  Row(product_id='2710', item='pork', category='Meat', price=6.739999771118164, type='supermarket'),
#  Row(product_id='2271', item='nut snack', category='Bakery & Snacks', price=1.1299999952316284, type='supermarket'),
#  Row(product_id='2055', item='make up remover', category='Personal Care', price=11.880000114440918, type='supermarket'),
#  Row(product_id='1730', item='house keeping products', category='Miscellaneous', price=8.5, type='supermarket'),
#  Row(product_id='922', item='curd cheese', category='Dairy', price=1.840000033378601, type='supermarket'),
#  Row(product_id='615', item='canned fruit', category='Produce', price=5.179999828338623, type='supermarket'),
#  Row(product_id='1848', item='ketchup', category='Condiments & Spices', price=2.890000104904175, type='supermarket'),
#  Row(product_id='1388', item='frozen fish', category='Miscellaneous', price=3.2100000381469727, type='supermarket'),
#  Row(product_id='2292', item='organic sausage', category='Meat', price=10.479999542236328, type='supermarket'),
#  Row(product_id='670', item='cereals', category='Bakery & Snacks', price=3.5999999046325684, type='supermarket'),
#  Row(product_id='2368', item='packaged fruit/vegetables', category='Produce', price=4.75, type='supermarket'),
#  Row(product_id='576', item='cake bar', category='Bakery & Snacks', price=1.0, type='supermarket'),
#  Row(product_id='1258', item='finished products', category='Bakery & Snacks', price=1.5800000429153442, type='supermarket'),
#  Row(product_id='614', item='canned fish', category='Miscellaneous', price=4.079999923706055, type='supermarket'),
#  Row(product_id='2272', item='nuts/prunes', category='Miscellaneous', price=2.549999952316284, type='supermarket'),
#  Row(product_id='3577', item='tidbits', category='Miscellaneous', price=6.010000228881836, type='supermarket'),
#  Row(product_id='978', item='dental care', category='Miscellaneous', price=3.8499999046325684, type='supermarket'),
#  Row(product_id='2727', item='prosecco', category='Beverages', price=7.570000171661377, type='supermarket'),
#  Row(product_id='1866', item='kitchen towels', category='Kitchen', price=5.409999847412109, type='supermarket'),
#  Row(product_id='2460', item='pasta', category='Pantry', price=4.429999828338623, type='supermarket'),
#  Row(product_id='112', item='abrasive cleaner', category='Cleaning & Hygiene', price=7.440000057220459, type='supermarket'),
#  Row(product_id='1269', item='fish', category='Miscellaneous', price=4.489999771118164, type='supermarket'),
#  Row(product_id='616', item='canned vegetables', category='Produce', price=5.820000171661377, type='supermarket'),
#  Row(product_id='2715', item='potato products', category='Miscellaneous', price=1.9199999570846558, type='supermarket'),
#  Row(product_id='836', item='cocoa drinks', category='Beverages', price=1.7300000190734863, type='supermarket'),
#  Row(product_id='3416', item='snack products', category='Bakery & Snacks', price=1.5800000429153442, type='supermarket'),
#  Row(product_id='955', item='decalcifier', category='Cleaning & Hygiene', price=7.039999961853027, type='supermarket'),
#  Row(product_id='3551', item='tea', category='Beverages', price=4.690000057220459, type='supermarket'),
#  Row(product_id='197', item='artif. sweetener', category='Condiments & Spices', price=3.490000009536743, type='supermarket'),
#  Row(product_id='535', item='brandy', category='Beverages', price=8.050000190734863, type='supermarket'),
#  Row(product_id='3456', item='specialty fat', category='Miscellaneous', price=6.659999847412109, type='supermarket'),
#  Row(product_id='3457', item='specialty vegetables', category='Produce', price=5.230000019073486, type='supermarket'),
#  Row(product_id='1987', item='liqueur', category='Miscellaneous', price=9.029999732971191, type='supermarket'),
#  Row(product_id='1249', item='female sanitary products', category='Personal Care', price=6.989999771118164, type='supermarket'),
#  Row(product_id='860', item='cookware', category='Kitchen', price=22.889999389648438, type='supermarket'),
#  Row(product_id='3458', item='spices', category='Condiments & Spices', price=4.909999847412109, type='supermarket'),
#  Row(product_id='2724', item='preservation products', category='Condiments & Spices', price=1.8899999856948853, type='supermarket'),
#  Row(product_id='2993', item='rubbing alcohol', category='Cleaning & Hygiene', price=5.079999923706055, type='supermarket'),
#  Row(product_id='2732', item='pudding powder', category='Miscellaneous', price=1.590000033378601, type='supermarket'),
#  Row(product_id='252', item='bags', category='Household', price=3.2699999809265137, type='supermarket'),
#  Row(product_id='3587', item='toilet cleaner', category='Cleaning & Hygiene', price=4.96999979019165, type='supermarket'),
#  Row(product_id='2059', item='male cosmetics', category='Personal Care', price=3.2300000190734863, type='supermarket'),
#  Row(product_id='1591', item='hair spray', category='Personal Care', price=7.119999885559082, type='supermarket'),
#  Row(product_id='3022', item='salad dressing', category='Condiments & Spices', price=5.25, type='supermarket'),
#  Row(product_id='3824', item='whisky', category='Beverages', price=5.96999979019165, type='supermarket'),
#  Row(product_id='2770', item='ready soups', category='Miscellaneous', price=7.840000152587891, type='supermarket'),
#  Row(product_id='2291', item='organic products', category='Miscellaneous', price=9.930000305175781, type='supermarket'),
#  Row(product_id='3340', item='skin care', category='Personal Care', price=6.420000076293945, type='supermarket'),
#  Row(product_id='1389', item='frozen fruits', category='Produce', price=5.860000133514404, type='supermarket'),
#  Row(product_id='880', item='cream', category='Dairy', price=4.210000038146973, type='supermarket'),
#  Row(product_id='1386', item='frozen chicken', category='Meat', price=10.210000038146973, type='supermarket'),
#  Row(product_id='858', item='cooking chocolate', category='Miscellaneous', price=7.670000076293945, type='supermarket'),
#  Row(product_id='279', item='bathroom cleaner', category='Cleaning & Hygiene', price=3.7300000190734863, type='supermarket'),
#  Row(product_id='1300', item='flower soil/fertilizer', category='Gardening', price=8.600000381469727, type='supermarket'),
#  Row(product_id='1867', item='kitchen utensil', category='Kitchen', price=8.880000114440918, type='supermarket')]

# %% [markdown]
# ### Market Basket Analysis
#
# To perform a Market basket analysis we have to search for the most frequent itemset to understand what customers tends to buy togethers.

# %%
# Preprocessing
from pyspark.sql.functions import collect_list, col, array_distinct

baskets = (purchase_df
            .join(product_df, on="product_id", how="inner")
            .filter(col("type") == "supermarket")
            .groupBy("InvoiceID")
            .agg(collect_list("item").alias("item"))
            .withColumn("item", array_distinct(col("item"))))

print(baskets.show())
# Out:
# +---------+--------------------+
# |InvoiceID|                item|
# +---------+--------------------+
# |        1|[whole milk, yogu...|
# |        2|[salty snack, who...|
# |        3|[misc. beverages,...|
# |        4|[sausage, hygiene...|
# |        5|[soda, pickled ve...|
# |        6| [curd, frankfurter]|
# |        7|[sausage, whole m...|
# |        8|  [soda, whole milk]|
# |        9| [beef, white bread]|
# |       10|[soda, frankfurte...|
# |       11|[frozen vegetable...|
# |       12|[butter, whole milk]|
# |       13|[tropical fruit, ...|
# |       14|[butter milk, spe...|
# |       15|[rolls/buns, saus...|
# |       16|[root vegetables,...|
# |       17|[frozen meals, de...|
# |       18|        [rolls/buns]|
# |       19|[cling film/bags,...|
# |       20|[canned beer, fro...|
# +---------+--------------------+
# only showing top 20 rows
# None

# %% [markdown]
# #### A-priori Algorithm
# The a-priori alghorithm allow us to find frequent itemsets expliting the monotonicity principle. In this section we are goint to explore the scalability of the algorothm inplementign three verison of them:
# - the original version with pruning
# - the version with hash table and Storing Pair Counts differently, that would allow us to consume less memory
# - the scalable version with spark

# %% [markdown]
# ##### Vanilla A-piori algorithm

# %%
from collections import defaultdict
from itertools import combinations
import random

baskets_list = [
    set(row.item) if hasattr(row, 'item') else set(row)
    for row in baskets.select("item").collect()
]

print(f"Numero di basket nel campione: {len(baskets_list)}")
num_transactions = len(baskets_list)
print(f"Numero di transazioni nel campione: {num_transactions}")
# Out:
# Numero di basket nel campione: 14963
# Numero di transazioni nel campione: 14963

# %%
import time
from functools import wraps

def timer(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"[TIMER] {func.__name__} executed in {end_time - start_time:.4f} seconds")
        return result
    return wrapper

# %%
# Step 1 — support for sigleton (L1)
@timer
def get_L1(baskets, min_support):
    item_counts = defaultdict(int)

    for basket in baskets:
        for item in basket:
            item_counts[frozenset([item])] += 1

    L1 = {
        itemset: count
        for itemset, count in item_counts.items()
        if count >= min_support
    }

    return L1

# %%
def all_subsets_frequent(itemset, subset_size, frequent_itemsets):
    """Verifica che tutti i sottoinsiemi di dimensione subset_size siano frequenti"""
    from itertools import combinations

    for subset in combinations(itemset, subset_size):
        if frozenset(subset) not in frequent_itemsets:
            return False
    return True

# %%
@timer
def generate_candidates(prev_L, k):
    candidates = set()
    prev_itemsets = list(prev_L.keys())

    for i in range(len(prev_itemsets)):
        for j in range(i + 1, len(prev_itemsets)):
            union = prev_itemsets[i] | prev_itemsets[j]

            if len(union) == k:
                # PRUNING: verify il all the subsets of dimension k-1 are frequent dimensione k-1 siano frequenti
                if all_subsets_frequent(union, k-1, prev_L):
                    candidates.add(union)

    return candidates


    return candidates

# %%
@timer
def count_candidates(baskets, candidates):
    counts = defaultdict(int)

    for basket in baskets:
        for candidate in candidates:
            if candidate.issubset(basket):
                counts[candidate] += 1

    return counts

# %%
@timer
def apriori(baskets, min_support):


    min_support_absolute = int(min_support * len(baskets))

    # Create singletons
    L1 = get_L1(baskets, min_support_absolute)
    L = dict(L1)

    #Start to create k-itemsets
    k = 2
    current_L = L1

    while current_L:
        Ck = generate_candidates(current_L, k)

        # If there arent any candidates, we can stop the algorithm
        if not Ck:
            break

        candidate_counts = count_candidates(baskets, Ck)

        current_L = {
            itemset: count
            for itemset, count in candidate_counts.items()
            if count >= min_support_absolute
        }

        L.update(current_L)
        k += 1

    return L

# %%
print(apriori(baskets_list, min_support = 0.002))
# Out:
# [TIMER] get_L1 executed in 0.0066 seconds
# [TIMER] generate_candidates executed in 0.0077 seconds
# [TIMER] count_candidates executed in 5.5261 seconds
# [TIMER] generate_candidates executed in 0.0059 seconds
# [TIMER] count_candidates executed in 0.2203 seconds
# [TIMER] apriori executed in 5.7674 seconds
# {frozenset({'whole milk'}): 2363, frozenset({'yogurt'}): 1285, frozenset({'sausage'}): 903, frozenset({'semi-finished bread'}): 142, frozenset({'salty snack'}): 281, frozenset({'pastry'}): 774, frozenset({'canned beer'}): 702, frozenset({'misc. beverages'}): 236, frozenset({'hygiene articles'}): 205, frozenset({'soda'}): 1453, frozenset({'pickled vegetables'}): 134, frozenset({'curd'}): 504, frozenset({'frankfurter'}): 565, frozenset({'rolls/buns'}): 1646, frozenset({'white bread'}): 359, frozenset({'beef'}): 508, frozenset({'whipped/sour cream'}): 654, frozenset({'frozen vegetables'}): 419, frozenset({'other vegetables'}): 1827, frozenset({'butter'}): 527, frozenset({'tropical fruit'}): 1014, frozenset({'sugar'}): 265, frozenset({'butter milk'}): 263, frozenset({'specialty chocolate'}): 239, froz
# %% [markdown]
# From now the a-priori algorithm collect the

# %% [markdown]
# ##### Optimized A-priori algorithm
# Following the book, i have implemented two way to save time and space.

# %%
from collections import defaultdict
import numpy as np
from functools import wraps

# Encoding in an hash table


def encode_baskets(baskets):
    #Convert items (string) to ids (int)
    item_to_id = {}
    id_to_item = {}
    item_id = 0

    for basket in baskets:
        for item in basket:
            if item not in item_to_id:
                item_to_id[item] = item_id
                id_to_item[item_id] = item
                item_id += 1

    baskets_encoded = [
        frozenset(item_to_id[item] for item in basket)
        for basket in baskets
    ]

    return item_to_id, id_to_item, baskets_encoded


def decode_itemsets(L_encoded, id_to_item):
    #Convert ids (int) to items (string)
    L_decoded = {}
    for itemset_ids, count in L_encoded.items():
        itemset_names = frozenset(id_to_item[item_id] for item_id in itemset_ids)
        L_decoded[itemset_names] = count
    return L_decoded


# Step 1 count sinmgleton
@timer
def get_L1(baskets, min_support):
    item_counts = defaultdict(int)

    for basket in baskets:
        for item in basket:
            item_counts[frozenset([item])] += 1

    L1 = {
        itemset: count
        for itemset, count in item_counts.items()
        if count >= min_support
    }

    return L1


# ============================================================================
# STEP 2: COUNT PAIRS - TRIANGULAR MATRIX
# ============================================================================

def create_triangular_matrix(n_items):
    """Crea array per coppie"""
    size = n_items * (n_items - 1) // 2
    return np.zeros(size, dtype=np.int32)


def pair_to_index(i, j, n):
    """Converte coppia (i,j) in indice k"""
    if i >= j:
        i, j = j, i
    return (i - 1) * n - i * (i + 1) // 2 + j - i


@timer
def count_pairs_triangular(baskets, L1, min_support, n_items):
    """Conta coppie usando Triangular Matrix"""

    # Estrai item frequenti
    frequent_items = set()
    for itemset in L1.keys():
        frequent_items.update(itemset)

    # Crea matrice triangolare
    pair_counts = create_triangular_matrix(n_items)

    # Conta le coppie
    for basket in baskets:
        frequent_in_basket = [item for item in basket if item in frequent_items]

        for i in range(len(frequent_in_basket)):
            for j in range(i + 1, len(frequent_in_basket)):
                item1 = frequent_in_basket[i]
                item2 = frequent_in_basket[j]

                if item1 > item2:
                    item1, item2 = item2, item1

                k = pair_to_index(item1, item2, n_items)
                pair_counts[k] += 1

    # Estrai coppie frequenti
    L2 = {}
    frequent_list = sorted(frequent_items)

    for i in range(len(frequent_list)):
        for j in range(i + 1, len(frequent_list)):
            item1, item2 = frequent_list[i], frequent_list[j]
            k = pair_to_index(item1, item2, n_items)
            count = int(pair_counts[k])

            if count >= min_support:
                L2[frozenset([item1, item2])] = count

    return L2


# ============================================================================
# STEP 2: COUNT PAIRS - TRIPLES METHOD
# ============================================================================

@timer
def count_pairs_triples(baskets, L1, min_support):
    """Conta coppie usando Triples Method (dizionario)"""

    # Estrai item frequenti
    frequent_items = set()
    for itemset in L1.keys():
        frequent_items.update(itemset)

    # Conta le coppie
    pair_counts = {}

    for basket in baskets:
        frequent_in_basket = [item for item in basket if item in frequent_items]

        for i in range(len(frequent_in_basket)):
            for j in range(i + 1, len(frequent_in_basket)):
                item1 = frequent_in_basket[i]
                item2 = frequent_in_basket[j]

                pair = (item1, item2) if item1 < item2 else (item2, item1)
                pair_counts[pair] = pair_counts.get(pair, 0) + 1

    # Estrai coppie frequenti
    L2 = {
        frozenset(pair): count
        for pair, count in pair_counts.items()
        if count >= min_support
    }

    return L2


# ============================================================================
# STEP 3+: LARGER ITEMSETS
# ============================================================================

@timer
def generate_candidates(prev_L, k):
    candidates = set()
    prev_itemsets = list(prev_L.keys())

    for i in range(len(prev_itemsets)):
        for j in range(i + 1, len(prev_itemsets)):
            union = prev_itemsets[i] | prev_itemsets[j]
            if len(union) == k:
                candidates.add(union)

    return candidates


@timer
def count_candidates(baskets, candidates):
    counts = defaultdict(int)

    for basket in baskets:
        for candidate in candidates:
            if candidate.issubset(basket):
                counts[candidate] += 1

    return counts



@timer
def apriori(baskets, min_support=0.01, method='triples'):
    """
    Algoritmo Apriori

    Args:
        baskets: lista di set/frozenset
        min_support: supporto minimo relativo (es. 0.01 = 1%)
        method: 'triples' o 'triangular'
    """

    # Encoding
    item_to_id, id_to_item, baskets_encoded = encode_baskets(baskets)
    n_items = len(item_to_id)
    min_support_count = int(min_support * len(baskets))

    print(f"Items: {n_items}, Baskets: {len(baskets)}, Min support: {min_support_count}")

    # Step 1: Singletons
    L1 = get_L1(baskets_encoded, min_support_count)
    print(f"L1: {len(L1)} itemset")

    # Step 2: Pairs
    if method == 'triangular':
        L2 = count_pairs_triangular(baskets_encoded, L1, min_support_count, n_items)
    elif method == 'triples':
        L2 = count_pairs_triples(baskets_encoded, L1, min_support_count)
    else:
        raise ValueError("method deve essere 'triangular' o 'triples'")

    print(f"L2: {len(L2)} itemset")

    # Step 3+: Itemsets più grandi
    L = {**L1, **L2}
    k = 3
    current_L = L2

    while current_L:
        Ck = generate_candidates(current_L, k)

        if not Ck:
            break

        candidate_counts = count_candidates(baskets_encoded, Ck)

        current_L = {
            itemset: count
            for itemset, count in candidate_counts.items()
            if count >= min_support_count
        }

        if current_L:
            print(f"L{k}: {len(current_L)} itemset")

        L.update(current_L)
        k += 1

    # Decode
    L_decoded = decode_itemsets(L, id_to_item)

    print(f"Totale: {len(L_decoded)} itemset frequenti")

    return L_decoded


# ============================================================================
# ESEMPIO D'USO
# ============================================================================

if __name__ == "__main__":

    # Test con Triples Method
    print("="*70)
    print("APRIORI CON TRIPLES METHOD")
    print("="*70)
    L_triples = apriori(baskets_list, min_support=0.002, method='triples')
    print(L_triples)

    print("\n" + "="*70)
    print("APRIORI CON TRIANGULAR MATRIX")
    print("="*70)
    L_triangular = apriori(baskets_list, min_support=0.002, method='triangular')

    # Verifica che i risultati siano identici
    print("\n" + "="*70)
    print(f"Risultati identici? {L_triples == L_triangular}")
    print("="*70)
# Out:
# ======================================================================
# APRIORI CON TRIPLES METHOD
# ======================================================================
# Items: 167, Baskets: 14963, Min support: 29
frozenset({'baking powder'}): 121, frozenset({'liquor'}): 103, frozenset({'male cosmetics'}): 37, frozenset({'fish'}): 29, frozenset({'cream cheese'}): 354, frozenset({'ham'}): 256, frozenset({'salt'}): 89, frozenset({'pork'}): 555, frozenset({'flower (seeds)'}): 69, frozenset({'ice cream'}): 227, frozenset({'pot plants'}): 117, frozenset({'waffles'}): 277, frozenset({'cat food'}): 177, frozenset({'vinegar'}): 51, frozenset({'chewing gum'}): 180, frozenset({'instant food products'}): 60, frozenset({'pasta'}): 121, frozenset({'chocolate marshmallow'}): 60, frozenset({'sweet spreads'}): 68, frozenset({'condensed milk'}): 98, frozenset({'house keeping products'}): 45, frozenset({'dishes'}): 135, frozenset({'popcorn'}): 48, frozenset({'female sanitary products'}): 40, frozenset({'dog food'}): 67, frozenset({'meat spreads'}): 35, frozenset({'spread cheese'}): 100, frozenset({'sauces'}): 44, frozenset({'rum'}): 32, frozenset({'finished products'}): 64, frozenset({'instant coffee'}): 59, frozenset({'artif. sweetener'}): 29, frozenset({'jam'}): 34, frozenset({'sparkling wine'}): 46, frozenset({'specialty fat'}): 29, frozenset({'specialty cheese'}): 72, frozenset({'frozen potato products'}): 72, frozenset({'turkey'}): 80, frozenset({'zwieback'}): 60, frozenset({'canned vegetables'}): 82, frozenset({'soups'}): 48, frozen ...
#
# ======================================================================
# APRIORI CON TRIANGULAR MATRIX
# ======================================================================
# Items: 167, Baskets: 14963, Min support: 29
# [TIMER] get_L1 executed in 0.0053 seconds
# L1: 130 itemset
# [TIMER] count_pairs_triangular executed in 0.0181 seconds
# L2: 217 itemset
# [TIMER] generate_candidates executed in 0.0032 seconds
# [TIMER] count_candidates executed in 1.3133 seconds
# Totale: 347 itemset frequenti
# [TIMER] apriori executed in 1.3488 seconds
#
# ======================================================================
# Risultati identici? True
# ======================================================================

# %% [markdown]
# ##### Spark version

# %%
from pyspark.ml.fpm import FPGrowth

fpGrowth = FPGrowth(itemsCol="item", minSupport=0.001, minConfidence=0.001)
model = fpGrowth.fit(baskets)

# Frequent itemsets
model.freqItemsets.show(truncate=False)

# Association rules
model.associationRules.collect()

# Predictions
model.transform(baskets).show(truncate=False)
# Out:
# +------------------------------------------+----+
# |items                                     |freq|
# +------------------------------------------+----+
# |[whole milk]                              |2363|
# |[other vegetables]                        |1827|
# |[other vegetables, whole milk]            |222 |
# |[rolls/buns]                              |1646|
# |[rolls/buns, whole milk]                  |209 |
# |[rolls/buns, other vegetables]            |158 |
# |[rolls/buns, other vegetables, whole milk]|18  |
# |[soda]                                    |1453|
# |[soda, whole milk]                        |174 |
# |[soda, other vegetables]                  |145 |
# |[soda, other vegetables, whole milk]      |17  |
# |[soda, rolls/buns]                        |121 |
# |[soda, rolls/buns, whole milk]            |15  |
# |[soda, rolls/buns, other vegetables]      |17  |
# |[yogurt]                                  |1285|
# |[yogurt, whole milk]                      |167 |
# |[yogurt, other vegetables]                |121 |
# |[yogurt, other vegetables, whole milk]    |17  |
# |[yogurt, rolls/buns]                      |117 |
# |[yogurt, rolls/buns, whole milk]          |20  |
# +------------------------------------------+----+
# only showing top 20 rows
# +---------+--------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# |16       |[root vegetables, detergent]                      |[whole milk, rolls/buns, yogurt, other vegetables, soda, tropical fruit, bottled water, sausage, citrus fruit, pastry, pip fruit, shopping bags, canned beer, bottled beer, whipped/sour cream, newspapers, frankfurter, brown bread, pork, domestic eggs, butter, fruit/vegetable juice, beef, curd, margarine, coffee, frozen vegetables, chicken, white bread, cream cheese, dessert, chocolate, napkins, hamburger meat, berries, uht-milk, onions, salty snack, waffles, butter milk, meat, misc. beverages, hard cheese, grapes, sliced cheese, hygiene articles, processed cheese]                                                                                                                                                                                                                                                                                                                          |
# |17       |[frozen meals, dental care]                       |[whole milk, other vegetables, rolls/buns, soda, yogurt, sausage]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |18       |[rolls/buns]                                      |[whole milk, other vegetables, soda, yogurt, root vegetables, tropical fruit, bottled water, sausage, citrus fruit, pastry, pip fruit, shopping bags, canned beer, bottled beer, whipped/sour cream, newspapers, frankfurter, brown bread, pork, domestic eggs, butter, fruit/vegetable juice, beef, curd, margarine, coffee, frozen vegetables, chicken, white bread, cream cheese, dessert, chocolate, napkins, hamburger meat, berries, uht-milk, onions, salty snack, waffles, long life bakery product, butter milk, ham, meat, frozen meals, beverages, specialty chocolate, misc. beverages, ice cream, oil, hard cheese, grapes, candy, specialty bar, hygiene articles, cat food, red/blush wine, processed cheese, soft cheese, detergent, packaged fruit/vegetables, seasonal products]                                                                                                                 |
# |19       |[cling film/bags, dish cleaner]                   |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |20       |[canned beer, frozen fish]                        |[whole milk, other vegetables, rolls/buns, soda, yogurt, root vegetables, tropical fruit, bottled water, sausage, citrus fruit, pastry, pip fruit, shopping bags, bottled beer, whipped/sour cream, newspapers, frankfurter, brown bread, pork, domestic eggs, butter, fruit/vegetable juice, beef, curd, margarine, coffee, frozen vegetables, chicken, white bread, chocolate, salty snack]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +---------+--------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
from pyspark.ml.fpm import FPGrowth

# Definiamo una griglia di valori per minSupport e minConfidence
support_values = [0.01, 0.005, 0.001, 0.0005, 0.0001]
confidence_values = [0.5, 0.3, 0.1, 0.05, 0.01, 0.001]

best_model = None
best_support = None
best_confidence = None

# Ciclo per trovare la prima combinazione che genera regole
for s in support_values:
    for c in confidence_values:
        print(f"Testing minSupport={s}, minConfidence={c}...")
        fpGrowth = FPGrowth(itemsCol="item", minSupport=s, minConfidence=c)
        model = fpGrowth.fit(items_df)
        rules = model.associationRules
        if rules.count() > 0:
            best_model = model
            best_support = s
            best_confidence = c
            print(f"Found rules with minSupport={s}, minConfidence={c}, rules={rules.count()}")
            break
    if best_model is not None:
        break

if best_model:
    print(f"\nBest parameters: minSupport={best_support}, minConfidence={best_confidence}")
    print("Frequent itemsets:")
    best_model.freqItemsets.show(truncate=False)
    print("Association rules:")
    best_model.associationRules.collect()
    print("Predictions:")
    best_model.transform(items_df).show(truncate=False)
else:
    print("No association rules found with the tested parameters.")
# Out:
# Testing minSupport=0.01, minConfidence=0.5...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[120], line 16
#      14 print(f"Testing minSupport={s}, minConfidence={c}...")
#      15 fpGrowth = FPGrowth(itemsCol="item", minSupport=s, minConfidence=c)
# ---> 16 model = fpGrowth.fit(items_df)
#      17 rules = model.associationRules
#      18 if rules.count() > 0:
#
# NameError: name 'items_df' is not defined

# %%
spark.stop()

# %% [markdown]
# # NUOVO DATASET
# Association rule su un dataset funzionante

# %%
from pyspark.sql.types import StructType, StructField, StringType

transactions_schema = StructType([
    StructField("Member_number", StringType(), True),
    StructField("Date", StringType(), True),
    StructField("itemDescription", StringType(), True)
])

groceries_dataset = spark.read.format("csv")\
    .option("header", "true")\
    .schema(transactions_schema)\
    .load("data/raw_data/groceries_dataset.csv")

items_df = groceries_dataset.groupBy("Member_number") \
    .agg(array_distinct(collect_list("itemDescription")).alias("items"))

items_df.head()



from pyspark.ml.fpm import FPGrowth

# Definiamo una griglia di valori per minSupport e minConfidence
support_values = [0.01, 0.005, 0.001, 0.0005, 0.0001]
confidence_values = [0.5, 0.3, 0.1, 0.05, 0.01, 0.001]

best_model = None
best_support = None
best_confidence = None

# Ciclo per trovare la prima combinazione che genera regole
for s in support_values:
    for c in confidence_values:
        print(f"Testing minSupport={s}, minConfidence={c}...")
        fpGrowth = FPGrowth(itemsCol="items", minSupport=s, minConfidence=c)
        model = fpGrowth.fit(items_df)
        rules = model.associationRules
        if rules.count() > 0:
            best_model = model
            best_support = s
            best_confidence = c
            print(f"Found rules with minSupport={s}, minConfidence={c}, rules={rules.count()}")
            break
    if best_model is not None:
        break

if best_model:
    print(f"\nBest parameters: minSupport={best_support}, minConfidence={best_confidence}")
    print("Frequent itemsets:")
    best_model.freqItemsets.show(truncate=False)
    print("Association rules:")
    best_model.associationRules.show(truncate=False)
    print("Predictions:")
    best_model.transform(items_df).show(truncate=False)
else:
    print("No association rules found with the tested parameters.")

# %%
spark.stop()

# %%
from pyspark.sql.functions import collect_list, array_distinct


online_retail = spark.read.format("csv")\
    .option("header", "true")\
    .load("data/raw_data/online_retail.csv")

online_retail.head()


items_df = online_retail.groupBy("CustomerID").agg(array_distinct(collect_list("Description")).alias("items"))

items_df.head()



from pyspark.ml.fpm import FPGrowth

# Definiamo una griglia di valori per minSupport e minConfidence
support_values = [0.01, 0.005, 0.001, 0.0005, 0.0001]
confidence_values = [0.5, 0.3, 0.1, 0.05, 0.01, 0.001]

best_model = None
best_support = None
best_confidence = None

# Ciclo per trovare la prima combinazione che genera regole
for s in support_values:
    for c in confidence_values:
        print(f"Testing minSupport={s}, minConfidence={c}...")
        fpGrowth = FPGrowth(itemsCol="items", minSupport=s, minConfidence=c)
        model = fpGrowth.fit(items_df)
        rules = model.associationRules
        if rules.count() > 0:
            best_model = model
            best_support = s
            best_confidence = c
            print(f"Found rules with minSupport={s}, minConfidence={c}, rules={rules.count()}")
            break
    if best_model is not None:
        break

if best_model:
    print(f"\nBest parameters: minSupport={best_support}, minConfidence={best_confidence}")
    print("Frequent itemsets:")
    best_model.freqItemsets.show(truncate=False)
    print("Association rules:")
    best_model.associationRules.show(truncate=False)
    print("Predictions:")
    best_model.transform(items_df).show(truncate=False)
else:
    print("No association rules found with the tested parameters.")

# %%
import pandas as pd
onl = pd.read_csv("data/raw_data/online_retail.csv")
onl
